# %% [markdown]
# <a href="https://colab.research.google.com/github/xmcodings/2020_cau_oss_hackathon/blob/master/hackathon_template_2020_Team7_Edit(jw).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임->모든 런타임 재설정"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 5시 (단, 발표자료는 11시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2020_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드 or 알고리즘이 적발될 경우
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
from tensorflow import keras
from keras.utils import np_utils

import numpy as np

# 데이터셋 다운로드
check = !if [ -d 'dataset/' ]; then echo "1" ; else echo "0"; fi
if (check[0] is '0' ):
  # !mkdir dataset
  # !wget 'https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/matlab.zip'
  # !unzip matlab.zip -d /content/dataset

# 데이터셋 로드
from scipy import io as spio
emnist = spio.loadmat("/content/dataset/matlab/emnist-balanced.mat")

x_train = emnist["dataset"][0][0][0][0][0][0]
y_train = emnist["dataset"][0][0][0][0][0][1]

x_test = emnist["dataset"][0][0][1][0][0][0]
y_test = emnist["dataset"][0][0][1][0][0][1]

# # 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 데이터 28x28 이미지화
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32')

# 총 클래스 개수
num_classes = y_test.shape[1]
input_shape = x_test.shape[1:]
# Out:
# --2020-08-29 04:17:21--  https://www.itl.nist.gov/iaui/vip/cs_links/EMNIST/matlab.zip
# Resolving www.itl.nist.gov (www.itl.nist.gov)... 132.163.4.36, 2610:20:6b01:4::36
# Connecting to www.itl.nist.gov (www.itl.nist.gov)|132.163.4.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 743900280 (709M) [application/zip]
# Saving to: ‘matlab.zip’
#
# matlab.zip          100%[===================>] 709.44M  85.0MB/s    in 8.1s
#
# 2020-08-29 04:17:29 (87.5 MB/s) - ‘matlab.zip’ saved [743900280/743900280]
#
# Archive:  matlab.zip
#   inflating: /content/dataset/matlab/emnist-balanced.mat
#   inflating: /content/dataset/matlab/emnist-byclass.mat
#   inflating: /content/dataset/matlab/emnist-bymerge.mat
#   inflating: /content/dataset/matlab/emnist-digits.mat
#   inflating: /content/dataset/matlab/emnist-letters.mat
#   inflating: /content/dataset/matlab/emnist-mnist.mat

# %% [markdown]
# # 사진 확인

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (112800, 28, 28, 1)
# (18800, 28, 28, 1)

# %%
import matplotlib.pyplot as plt 
import cv2 as cv

label = []

rows = 5 # defining no. of rows in figure
cols = 6 # defining no. of colums in figure

f = plt.figure(figsize=(2*cols,2*rows)) # defining a figure 

for i in range(rows*cols): 
    f.add_subplot(rows,cols,i+1) # adding sub plot to figure on each iteration
    plt.imshow(x_train[i].reshape([28,28]),cmap="Blues") 
    plt.axis("off")
    plt.title(str(y_train[i]), y=-0.15,color="green")

# %% [markdown]
# # **2. 데이터 전처리**

# %%
from skimage import filters
from skimage import exposure
from skimage.util import random_noise


import random 



# 데이터 전처리 (예: normalization)
x_train_after = x_train / 255.0
x_test_after = x_test / 255.0

# augmentation


#1. sigmoid correction
#x_train_after = exposure.adjust_sigmoid(x_train_after)
#x_test_after = exposure.adjust_sigmoid(x_test_after)

#2. tighten image contrast

#v_min, v_max = np.percentile(x_train_after[5], (0.2, 98.8)) # 기준을 5번째 사진으로

#x_train_after = exposure.rescale_intensity(x_train_after, in_range=(v_min, v_max))
#x_test_after = exposure.rescale_intensity(x_test_after, in_range=(v_min, v_max))

#3. flip random data

# horizontal
augment_num = 0

aug_record = []
for i in tqdm(range(augment_num)):
  rand = random.randint(0, 112799)
  x_train_after[rand] = x_train_after[rand][::-1, :]
  aug_record.append(rand)

print("horizontal aug record: ", aug_record)

print("     ")

# vertical

aug_record = []

for i in tqdm(range(augment_num)):
  rand = random.randint(0, 112799)
  x_train_after[rand] = x_train_after[rand][:, ::-1]
  aug_record.append(rand)

print("vertical aug record: ", aug_record)
# 4. random noise

x_train_after = random_noise(x_train_after)
x_test_after = random_noise(x_test_after)
# Out:
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# horizontal aug record:  []
#
# vertical aug record:  []

# %%
rows = 5 # defining no. of rows in figure
cols = 6 # defining no. of colums in figure

f = plt.figure(figsize=(2*cols,2*rows)) # defining a figure 

for i in range(rows*cols): 
    f.add_subplot(rows,cols,i+1) # adding sub plot to figure on each iteration
    plt.imshow(x_train_after[i].reshape([28,28]),cmap="Blues") 
    plt.axis("off")
    plt.title(str(y_train[i]), y=-0.15,color="green")

# %%
# maybe this might work....
'''
from skimage import filters
from tqdm import tqdm


out = np.empty((112800, 28, 28, 1))
for img in tqdm(x_train):
  camera = img
  val = filters.threshold_otsu(camera)
  mask = camera < val
  s = mask.flatten().reshape(28,28,1)
  out[:] = s

print(out)
'''
# Out:
# '\nfrom skimage import filters\nfrom tqdm import tqdm\n\n\nout = np.empty((112800, 28, 28, 1))\nfor img in tqdm(x_train):\n  camera = img\n  val = filters.threshold_otsu(camera)\n  mask = camera < val\n  s = mask.flatten().reshape(28,28,1)\n  out[:] = s\n\nprint(out)\n'

# %% [markdown]
# # **3. 모델 생성**

# %%
def make_model():

  model = keras.models.Sequential([
                      keras.layers.Conv2D(32, (5,5), padding  ="same", activation = 'relu', input_shape = (28, 28, 1)),  # layer 1
                      keras.layers.MaxPool2D((2,2)),                                                  # layer 2
                      keras.layers.Dropout(0.3),
                      keras.layers.Conv2D(64, (5,5), padding  ="same", activation = 'relu'),                            # layer 4
                      keras.layers.MaxPool2D((2,2)),                                                  # layer 5
                      keras.layers.Dropout(0.25),
                      keras.layers.Flatten(),
                      keras.layers.Dense(512, activation='relu'),
                      keras.layers.Dropout(0.4),
                      keras.layers.Dense(256, activation='relu'),
                      keras.layers.Dense(128, activation='relu'),
                      keras.layers.Dense(47, activation = 'softmax')]) # output layer
  return model

# %%
min_lr = 0.00000001
def scheduler(epoch, lr):
  
  if epoch < 3:
    return lr
  if lr < min_lr:
    return lr
  else:
    newlr = lr * tf.math.exp(-0.1)
    
    print("reducing lr to ", newlr)
    return newlr

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ReduceLROnPlateau

optimizer = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)

cnn_m = make_model()

#모델 compile

cnn_m.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

#모델 학습 및 callback

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_jinwon_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')
RLP = ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.2,min_lr=0.0000001)

cnn_m.fit(x_train_after, y_train, batch_size = 256, epochs = 50, shuffle=True, callbacks=[cp_callback, RLP], validation_data=(x_test_after, y_test))
# Out:
# Epoch 1/50
# 436/441 [============================>.] - ETA: 0s - loss: 1.0185 - accuracy: 0.6882
# Epoch 00001: val_accuracy improved from -inf to 0.81739, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 1.0142 - accuracy: 0.6891 - val_loss: 0.4970 - val_accuracy: 0.8174
# Epoch 2/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.4901 - accuracy: 0.8299
# Epoch 00002: val_accuracy improved from 0.81739 to 0.85968, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.4899 - accuracy: 0.8300 - val_loss: 0.4073 - val_accuracy: 0.8597
# Epoch 3/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.4192 - accuracy: 0.8522
# Epoch 00003: val_accuracy improved from 0.85968 to 0.87144, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.4191 - accuracy: 0.8522 - val_loss: 0.3621 - val_accuracy: 0.8714
# Epoch 4/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.3834 - accuracy: 0.8638
# Epoch 00004: val_accuracy did not improve from 0.87144
# 441/441 [==============================] - 5s 11ms/step - loss: 0.3835 - accuracy: 0.8638 - val_loss: 0.3736 - val_accuracy: 0.8632
# Epoch 5/50
# 441/441 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.8701
# Epoch 00005: val_accuracy improved from 0.87144 to 0.87590, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 11ms/step - loss: 0.3579 - accuracy: 0.8701 - val_loss: 0.3444 - val_accuracy: 0.8759
# Epoch 6/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.3421 - accuracy: 0.8762
# Epoch 00006: val_accuracy improved from 0.87590 to 0.87707, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.3419 - accuracy: 0.8762 - val_loss: 0.3427 - val_accuracy: 0.8771
# Epoch 7/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.3281 - accuracy: 0.8818
# Epoch 00007: val_accuracy improved from 0.87707 to 0.88410, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.3280 - accuracy: 0.8819 - val_loss: 0.3288 - val_accuracy: 0.8841
# Epoch 8/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.3171 - accuracy: 0.8834
# Epoch 00008: val_accuracy did not improve from 0.88410
# 441/441 [==============================] - 5s 11ms/step - loss: 0.3172 - accuracy: 0.8834 - val_loss: 0.3295 - val_accuracy: 0.8832
# Epoch 9/50
# 441/441 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8862
# Epoch 00009: val_accuracy improved from 0.88410 to 0.88761, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.3089 - accuracy: 0.8862 - val_loss: 0.3216 - val_accuracy: 0.8876
# Epoch 10/50
# 441/441 [==============================] - ETA: 0s - loss: 0.3009 - accuracy: 0.8888
# Epoch 00010: val_accuracy did not improve from 0.88761
# 441/441 [==============================] - 5s 11ms/step - loss: 0.3009 - accuracy: 0.8888 - val_loss: 0.3283 - val_accuracy: 0.8816
# Epoch 11/50
# 437/441 [============================>.] - ETA: 0s - loss: 0.2940 - accuracy: 0.8917
# Epoch 00011: val_accuracy did not improve from 0.88761
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2945 - accuracy: 0.8916 - val_loss: 0.3218 - val_accuracy: 0.8876
# Epoch 12/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2887 - accuracy: 0.8941
# Epoch 00012: val_accuracy did not improve from 0.88761
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2888 - accuracy: 0.8940 - val_loss: 0.3253 - val_accuracy: 0.8837
# Epoch 13/50
# 438/441 [============================>.] - ETA: 0s - loss: 0.2540 - accuracy: 0.9038
# Epoch 00013: val_accuracy improved from 0.88761 to 0.89261, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2539 - accuracy: 0.9038 - val_loss: 0.3057 - val_accuracy: 0.8926
# Epoch 14/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9065
# Epoch 00014: val_accuracy did not improve from 0.89261
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2430 - accuracy: 0.9065 - val_loss: 0.3076 - val_accuracy: 0.8922
# Epoch 15/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9079
# Epoch 00015: val_accuracy improved from 0.89261 to 0.89356, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2408 - accuracy: 0.9079 - val_loss: 0.3024 - val_accuracy: 0.8936
# Epoch 16/50
# 437/441 [============================>.] - ETA: 0s - loss: 0.2380 - accuracy: 0.9084
# Epoch 00016: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2381 - accuracy: 0.9085 - val_loss: 0.3023 - val_accuracy: 0.8927
# Epoch 17/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2359 - accuracy: 0.9091
# Epoch 00017: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2359 - accuracy: 0.9092 - val_loss: 0.3043 - val_accuracy: 0.8922
# Epoch 18/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2323 - accuracy: 0.9106
# Epoch 00018: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2323 - accuracy: 0.9106 - val_loss: 0.3020 - val_accuracy: 0.8924
# Epoch 19/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2339 - accuracy: 0.9102
# Epoch 00019: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2339 - accuracy: 0.9102 - val_loss: 0.3041 - val_accuracy: 0.8931
# Epoch 20/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2307 - accuracy: 0.9114
# Epoch 00020: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2307 - accuracy: 0.9114 - val_loss: 0.3054 - val_accuracy: 0.8914
# Epoch 21/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2288 - accuracy: 0.9108
# Epoch 00021: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2289 - accuracy: 0.9108 - val_loss: 0.3047 - val_accuracy: 0.8927
# Epoch 22/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2197 - accuracy: 0.9143
# Epoch 00022: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2196 - accuracy: 0.9143 - val_loss: 0.3018 - val_accuracy: 0.8932
# Epoch 23/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2202 - accuracy: 0.9141
# Epoch 00023: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2202 - accuracy: 0.9142 - val_loss: 0.3027 - val_accuracy: 0.8931
# Epoch 24/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2212 - accuracy: 0.9133
# Epoch 00024: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2213 - accuracy: 0.9132 - val_loss: 0.3025 - val_accuracy: 0.8931
# Epoch 25/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9147
# Epoch 00025: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2190 - accuracy: 0.9147 - val_loss: 0.3006 - val_accuracy: 0.8934
# Epoch 26/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2184 - accuracy: 0.9150
# Epoch 00026: val_accuracy did not improve from 0.89356
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2183 - accuracy: 0.9149 - val_loss: 0.3013 - val_accuracy: 0.8931
# Epoch 27/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9154
# Epoch 00027: val_accuracy improved from 0.89356 to 0.89378, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2180 - accuracy: 0.9154 - val_loss: 0.3024 - val_accuracy: 0.8938
# Epoch 28/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2195 - accuracy: 0.9148
# Epoch 00028: val_accuracy improved from 0.89378 to 0.89394, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2195 - accuracy: 0.9148 - val_loss: 0.3032 - val_accuracy: 0.8939
# Epoch 29/50
# 437/441 [============================>.] - ETA: 0s - loss: 0.2168 - accuracy: 0.9154
# Epoch 00029: val_accuracy did not improve from 0.89394
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2167 - accuracy: 0.9154 - val_loss: 0.3015 - val_accuracy: 0.8936
# Epoch 30/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2167 - accuracy: 0.9158
# Epoch 00030: val_accuracy did not improve from 0.89394
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2169 - accuracy: 0.9157 - val_loss: 0.3018 - val_accuracy: 0.8937
# Epoch 31/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2156 - accuracy: 0.9160
# Epoch 00031: val_accuracy did not improve from 0.89394
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2156 - accuracy: 0.9160 - val_loss: 0.3020 - val_accuracy: 0.8935
# Epoch 32/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2156 - accuracy: 0.9161
# Epoch 00032: val_accuracy did not improve from 0.89394
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2154 - accuracy: 0.9162 - val_loss: 0.3021 - val_accuracy: 0.8938
# Epoch 33/50
# 436/441 [============================>.] - ETA: 0s - loss: 0.2163 - accuracy: 0.9159
# Epoch 00033: val_accuracy did not improve from 0.89394
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2159 - accuracy: 0.9161 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 34/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9146
# Epoch 00034: val_accuracy improved from 0.89394 to 0.89404, saving model to /content/checkpoint_jinwon_best.h5
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2176 - accuracy: 0.9146 - val_loss: 0.3020 - val_accuracy: 0.8940
# Epoch 35/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2160 - accuracy: 0.9159
# Epoch 00035: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2160 - accuracy: 0.9159 - val_loss: 0.3020 - val_accuracy: 0.8940
# Epoch 36/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2146 - accuracy: 0.9163
# Epoch 00036: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2148 - accuracy: 0.9162 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 37/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2163 - accuracy: 0.9156
# Epoch 00037: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2163 - accuracy: 0.9156 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 38/50
# 439/441 [============================>.] - ETA: 0s - loss: 0.2148 - accuracy: 0.9163
# Epoch 00038: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2149 - accuracy: 0.9162 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 39/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9155
# Epoch 00039: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2152 - accuracy: 0.9155 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 40/50
# 436/441 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9153
# Epoch 00040: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2164 - accuracy: 0.9153 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 41/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2156 - accuracy: 0.9163
# Epoch 00041: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2156 - accuracy: 0.9163 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 42/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2158 - accuracy: 0.9160
# Epoch 00042: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2158 - accuracy: 0.9160 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 43/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9164
# Epoch 00043: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2146 - accuracy: 0.9164 - val_loss: 0.3020 - val_accuracy: 0.8939
# Epoch 44/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9162
# Epoch 00044: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2168 - accuracy: 0.9162 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 45/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9168
# Epoch 00045: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2154 - accuracy: 0.9168 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 46/50
# 438/441 [============================>.] - ETA: 0s - loss: 0.2143 - accuracy: 0.9162
# Epoch 00046: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2146 - accuracy: 0.9161 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 47/50
# 438/441 [============================>.] - ETA: 0s - loss: 0.2153 - accuracy: 0.9165
# Epoch 00047: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2153 - accuracy: 0.9164 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 48/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.9161
# Epoch 00048: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 12ms/step - loss: 0.2156 - accuracy: 0.9162 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 49/50
# 440/441 [============================>.] - ETA: 0s - loss: 0.2151 - accuracy: 0.9159
# Epoch 00049: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2150 - accuracy: 0.9159 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 50/50
# 441/441 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9164
# Epoch 00050: val_accuracy did not improve from 0.89404
# 441/441 [==============================] - 5s 11ms/step - loss: 0.2157 - accuracy: 0.9164 - val_loss: 0.3020 - val_accuracy: 0.8938

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team07'

# 트레이닝된 전체 모델을 저장합니다.
#cnn_m.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team07'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 588/588 [==============================] - 2s 3ms/step - loss: 0.3020 - accuracy: 0.8938
# [0.3020220696926117, 0.8937765955924988]
